# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dfs = pd.read_csv("quitSmokingState.csv")
dfc = pd.read_csv("deathRatesStates.csv")

# %%
dfs.head()
# Out:
#         Location  All Adults  Non-Hispanic White Non-Hispanic Black Hispanic  \
# 0  United States        0.57                0.54               0.69     0.60
# 1        Alabama        0.64                0.63               0.71      NSD
# 2         Alaska        0.56                0.55               0.58      NSD
# 3        Arizona        0.55                0.47               0.66     0.65
# 4       Arkansas        0.59                0.57               0.70     0.59
#
#   Asian and Native Hawaiian or Pacific Islander  \
# 0                                          0.67
# 1                                           NSD
# 2                                           NSD
# 3                                          0.83
# 4                                           NSD
#
#   American Indian/ Alaska Native Other  Footnotes
# 0                           0.51  0.58        1.0
# 1                           0.49  0.71        NaN
# 2                           0.59  0.64        NaN
# ...

# %%
dfc.head()
# Out:
#         Location  Death Rate per 100,000
# 0  United States                   723.6
# 1        Alabama                   918.1
# 2         Alaska                   700.3
# 3        Arizona                   669.2
# 4       Arkansas                   876.6

# %%
ax = dfs.plot.bar(y='All Adults', rot=0, figsize=(20,10), ylim = (0.4, .8))
plt.savefig("figures/FullQuitingSmokingPerState")

# %%
ax = dfc.plot.bar(y='Death Rate per 100,000', rot=0, figsize=(20,10))
plt.savefig("figures/FullCOVIDDeathRatesStates")

# %%
dfs["COVID Death Rate"] = dfc["Death Rate per 100,000"]

# %%
dfs.head()
# Out:
#         Location  All Adults  Non-Hispanic White Non-Hispanic Black Hispanic  \
# 0  United States        0.57                0.54               0.69     0.60
# 1        Alabama        0.64                0.63               0.71      NSD
# 2         Alaska        0.56                0.55               0.58      NSD
# 3        Arizona        0.55                0.47               0.66     0.65
# 4       Arkansas        0.59                0.57               0.70     0.59
#
#   Asian and Native Hawaiian or Pacific Islander  \
# 0                                          0.67
# 1                                           NSD
# 2                                           NSD
# 3                                          0.83
# 4                                           NSD
#
#   American Indian/ Alaska Native Other  Footnotes  COVID Death Rate
# 0                           0.51  0.58        1.0             723.6
# 1                           0.49  0.71        NaN             918.1
# ...

# %%
df_new = dfs.drop(columns = ["Non-Hispanic White", "Non-Hispanic Black", "Hispanic", "Asian and Native Hawaiian or Pacific Islander", "American Indian/ Alaska Native", "Other", "Footnotes"])

# %%
df_new.head()
# Out:
#         Location  All Adults  COVID Death Rate
# 0  United States        0.57             723.6
# 1        Alabama        0.64             918.1
# 2         Alaska        0.56             700.3
# 3        Arizona        0.55             669.2
# 4       Arkansas        0.59             876.6

# %%
# fig = plt.figure(figsize = [20,20])
# sns.heatmap(df_new.corr(),annot = True, cmap = 'coolwarm', center = 0)
# plt.show()++

# %%
plt.figure(figsize=(10,5))
plt.plot(df_new["All Adults"], df_new["COVID Death Rate"], ".")
plt.title("Quitting Smoking vs COVID Death Rate Per State")
plt.xlabel("Quitting Smoking Rate")
plt.ylabel("COVID Death Rate")
plt.savefig("figures/ScatterWithOutliers")

# %%
## create a linear regression line
sns.lmplot(x= "All Adults", y= "COVID Death Rate",data= df_new, fit_reg=True, line_kws={'color': 'red'})

plt.show()
plt.savefig("figures/BadRegressionLine")

# %%
correlation = column_1.corr(df[])
