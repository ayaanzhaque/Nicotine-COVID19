# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv")

# %%
df.head(10)
# Out:
#   iso_code      continent location        date  total_cases  new_cases  \
# 0      ABW  North America    Aruba  2020-03-13          2.0        2.0
# 1      ABW  North America    Aruba  2020-03-20          4.0        2.0
# 2      ABW  North America    Aruba  2020-03-24         12.0        8.0
# 3      ABW  North America    Aruba  2020-03-25         17.0        5.0
# 4      ABW  North America    Aruba  2020-03-26         19.0        2.0
# 5      ABW  North America    Aruba  2020-03-27         28.0        9.0
# 6      ABW  North America    Aruba  2020-03-28         28.0        0.0
# 7      ABW  North America    Aruba  2020-03-29         28.0        0.0
# 8      ABW  North America    Aruba  2020-03-30         50.0       22.0
# 9      ABW  North America    Aruba  2020-04-01         55.0        5.0
#
#    total_deaths  new_deaths  total_cases_per_million  new_cases_per_million  \
# 0           0.0         0.0                   18.733                 18.733
# 1           0.0         0.0                   37.465                 18.733
# 2           0.0         0.0                  112.395                 74.930
# 3           0.0         0.0                  159.227                 46.831
# 4           0.0         0.0                  177.959                 18.733
# 5           0.0         0.0                  262.256                 84.296
# 6           0.0         0.0                  262.256                  0.000
# 7           0.0         0.0                  262.256                  0.000
# 8           0.0         0.0                  468.314                206.058
# 9           0.0         0.0                  515.145                 46.831
#
#    ...  aged_70_older  gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0  ...          7.452       35973.781              NaN                    NaN
# 1  ...          7.452       35973.781              NaN                    NaN
# 2  ...          7.452       35973.781              NaN                    NaN
# 3  ...          7.452       35973.781              NaN                    NaN
# 4  ...          7.452       35973.781              NaN                    NaN
# 5  ...          7.452       35973.781              NaN                    NaN
# 6  ...          7.452       35973.781              NaN                    NaN
# 7  ...          7.452       35973.781              NaN                    NaN
# 8  ...          7.452       35973.781              NaN                    NaN
# 9  ...          7.452       35973.781              NaN                    NaN
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                11.62             NaN           NaN                     NaN
# 1                11.62             NaN           NaN                     NaN
# 2                11.62             NaN           NaN                     NaN
# 3                11.62             NaN           NaN                     NaN
# 4                11.62             NaN           NaN                     NaN
# 5                11.62             NaN           NaN                     NaN
# 6                11.62             NaN           NaN                     NaN
# 7                11.62             NaN           NaN                     NaN
# 8                11.62             NaN           NaN                     NaN
# 9                11.62             NaN           NaN                     NaN
#
#   hospital_beds_per_thousand  life_expectancy
# 0                        NaN            76.29
# 1                        NaN            76.29
# 2                        NaN            76.29
# 3                        NaN            76.29
# 4                        NaN            76.29
# 5                        NaN            76.29
# 6                        NaN            76.29
# 7                        NaN            76.29
# 8                        NaN            76.29
# 9                        NaN            76.29
#
# [10 rows x 34 columns]

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'total_deaths', 'new_deaths', 'total_cases_per_million',
#        'new_cases_per_million', 'total_deaths_per_million',
#        'new_deaths_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'tests_units',
#        'stringency_index', 'population', 'population_density', 'median_age',
#        'aged_65_older', 'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy'],
#       dtype='object')

# %%
#looking for missing values
df.isnull()
df.isnull().sum()
# Out:
# iso_code                              64
# continent                            276
# location                               0
# date                                   0
# total_cases                          355
# new_cases                            355
# total_deaths                         355
# new_deaths                           355
# total_cases_per_million              419
# new_cases_per_million                419
# total_deaths_per_million             419
# new_deaths_per_million               419
# new_tests                          22741
# total_tests                        22513
# total_tests_per_thousand           22513
# new_tests_per_thousand             22741
# new_tests_smoothed                 21568
# new_tests_smoothed_per_thousand    21568
# tests_units                        20803
# stringency_index                    6173
# population                            64
# population_density                  1507
# median_age                          3343
# aged_65_older                       3779
# aged_70_older                       3498
# gdp_per_capita                      3709
# extreme_poverty                    13552
# cardiovasc_death_rate               3334
# diabetes_prevalence                 2313
# female_smokers                      9540
# male_smokers                        9826
# handwashing_facilities             19653
# hospital_beds_per_thousand          6064
# life_expectancy                      466
# dtype: int64

# %%
df.tail()
# Out:
#       iso_code continent       location        date  total_cases  new_cases  \
# 33412      NaN       NaN  International  2020-02-28        705.0        0.0
# 33413      NaN       NaN  International  2020-02-29        705.0        0.0
# 33414      NaN       NaN  International  2020-03-01        705.0        0.0
# 33415      NaN       NaN  International  2020-03-02        705.0        0.0
# 33416      NaN       NaN  International  2020-03-10        696.0       -9.0
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 33412           4.0         0.0                      NaN
# 33413           6.0         2.0                      NaN
# 33414           6.0         0.0                      NaN
# 33415           6.0         0.0                      NaN
# 33416           7.0         1.0                      NaN
#
#        new_cases_per_million  ...  aged_70_older  gdp_per_capita  \
# 33412                    NaN  ...            NaN             NaN
# 33413                    NaN  ...            NaN             NaN
# 33414                    NaN  ...            NaN             NaN
# 33415                    NaN  ...            NaN             NaN
# 33416                    NaN  ...            NaN             NaN
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 33412              NaN                    NaN                  NaN
# 33413              NaN                    NaN                  NaN
# 33414              NaN                    NaN                  NaN
# 33415              NaN                    NaN                  NaN
# 33416              NaN                    NaN                  NaN
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 33412             NaN           NaN                     NaN
# 33413             NaN           NaN                     NaN
# 33414             NaN           NaN                     NaN
# 33415             NaN           NaN                     NaN
# 33416             NaN           NaN                     NaN
#
#       hospital_beds_per_thousand  life_expectancy
# 33412                        NaN              NaN
# 33413                        NaN              NaN
# 33414                        NaN              NaN
# 33415                        NaN              NaN
# 33416                        NaN              NaN
#
# [5 rows x 34 columns]

# %%
corr = df.corr()
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
cax = ax.matshow(corr, cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(corr.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(corr.columns)
ax.set_yticklabels(corr.columns)
plt.show()
plt.savefig("owid_figures/correlation_matrix")

# %%
fig = plt.figure(figsize = [20,20])
sns.heatmap(df.corr(),annot = True, cmap = 'coolwarm', center = 0)
plt.show()
plt.savefig("owid_figures/corrmatrix_with_values")

# %%
corr.head()
# Out:
#                          total_cases  new_cases  total_deaths  new_deaths  \
# total_cases                 1.000000   0.967150      0.978311    0.766184
# new_cases                   0.967150   1.000000      0.956274    0.865841
# total_deaths                0.978311   0.956274      1.000000    0.814854
# new_deaths                  0.766184   0.865841      0.814854    1.000000
# total_cases_per_million     0.076071   0.061317      0.068261    0.039869
#
#                          total_cases_per_million  new_cases_per_million  \
# total_cases                             0.076071               0.053170
# new_cases                               0.061317               0.074996
# total_deaths                            0.068261               0.039670
# new_deaths                              0.039869               0.054455
# total_cases_per_million                 1.000000               0.437471
#
#                          total_deaths_per_million  new_deaths_per_million  \
# total_cases                              0.085451                0.034682
# new_cases                                0.060198                0.048800
# total_deaths                             0.131027                0.043367
# new_deaths                               0.071688                0.113705
# total_cases_per_million                  0.572934                0.165122
#
#                          new_tests  total_tests  ...  aged_70_older  \
# total_cases               0.935598     0.923900  ...       0.016633
# new_cases                 0.879047     0.799974  ...       0.004498
# total_deaths              0.831733     0.811516  ...       0.040455
# new_deaths                0.549694     0.419483  ...       0.024462
# total_cases_per_million   0.186001     0.219031  ...       0.075101
#
#                          gdp_per_capita  extreme_poverty  \
# total_cases                    0.013086        -0.029114
# new_cases                      0.004240        -0.028006
# total_deaths                   0.020049        -0.034856
# new_deaths                     0.008846        -0.035537
# total_cases_per_million        0.383365        -0.197413
#
#                          cardiovasc_death_rate  diabetes_prevalence  \
# total_cases                          -0.029883             0.015566
# new_cases                            -0.028052             0.019889
# total_deaths                         -0.049859             0.005122
# new_deaths                           -0.046406             0.011897
# total_cases_per_million              -0.189485             0.070896
#
#                          female_smokers  male_smokers  handwashing_facilities  \
# total_cases                   -0.004172     -0.006232                0.022107
# new_cases                     -0.015605     -0.012515                0.026696
# total_deaths                   0.010899     -0.014377                0.024985
# new_deaths                    -0.003311     -0.018714                0.032255
# total_cases_per_million        0.096878     -0.049422                0.208836
#
#                          hospital_beds_per_thousand  life_expectancy
# total_cases                               -0.010671         0.008322
# new_cases                                 -0.019929         0.000271
# total_deaths                              -0.011139         0.022567
# new_deaths                                -0.020051         0.013819
# total_cases_per_million                    0.025616         0.250020
#
# [5 rows x 29 columns]

# %%
# df.location.unique()

# %%
df_usa = df[df.location == "United States"]

# %%
df_usa.tail(20)
# Out:
#       iso_code      continent       location        date  total_cases  \
# 31433      USA  North America  United States  2020-07-10    3118008.0
# 31434      USA  North America  United States  2020-07-11    3184633.0
# 31435      USA  North America  United States  2020-07-12    3247684.0
# 31436      USA  North America  United States  2020-07-13    3304942.0
# 31437      USA  North America  United States  2020-07-14    3363056.0
# 31438      USA  North America  United States  2020-07-15    3431574.0
# 31439      USA  North America  United States  2020-07-16    3499291.0
# 31440      USA  North America  United States  2020-07-17    3576221.0
# 31441      USA  North America  United States  2020-07-18    3647715.0
# 31442      USA  North America  United States  2020-07-19    3711464.0
# 31443      USA  North America  United States  2020-07-20    3773260.0
# 31444      USA  North America  United States  2020-07-21    3830010.0
# 31445      USA  North America  United States  2020-07-22    3902058.0
# 31446      USA  North America  United States  2020-07-23    3970906.0
# 31447      USA  North America  United States  2020-07-24    4034102.0
# 31448      USA  North America  United States  2020-07-25    4112529.0
# 31449      USA  North America  United States  2020-07-26    4178027.0
# 31450      USA  North America  United States  2020-07-27    4234020.0
# 31451      USA  North America  United States  2020-07-28    4290263.0
# 31452      USA  North America  United States  2020-07-29    4351997.0
#
#        new_cases  total_deaths  new_deaths  total_cases_per_million  \
# 31433    63004.0      133291.0       982.0                 9419.888
# 31434    66625.0      134097.0       806.0                 9621.171
# 31435    63051.0      134814.0       717.0                 9811.656
# 31436    57258.0      135205.0       391.0                 9984.639
# 31437    58114.0      135605.0       400.0                10160.209
# 31438    68518.0      136466.0       861.0                10367.210
# 31439    67717.0      137419.0       953.0                10571.792
# 31440    76930.0      138358.0       939.0                10804.207
# 31441    71494.0      139266.0       908.0                11020.199
# 31442    63749.0      140119.0       853.0                11212.793
# 31443    61796.0      140534.0       415.0                11399.486
# 31444    56750.0      140906.0       372.0                11570.935
# 31445    72048.0      142066.0      1160.0                11788.601
# 31446    68848.0      143190.0      1124.0                11996.599
# 31447    63196.0      144242.0      1052.0                12187.522
# 31448    78427.0      145546.0      1304.0                12424.460
# 31449    65498.0      146460.0       914.0                12622.337
# 31450    55993.0      146935.0       475.0                12791.499
# 31451    56243.0      148011.0      1076.0                12961.416
# 31452    61734.0      149256.0      1245.0                13147.922
#
#        new_cases_per_million  ...  aged_70_older  gdp_per_capita  \
# 31433                190.343  ...          9.732       54225.446
# 31434                201.282  ...          9.732       54225.446
# 31435                190.485  ...          9.732       54225.446
# 31436                172.984  ...          9.732       54225.446
# 31437                175.570  ...          9.732       54225.446
# 31438                207.001  ...          9.732       54225.446
# 31439                204.581  ...          9.732       54225.446
# 31440                232.415  ...          9.732       54225.446
# 31441                215.992  ...          9.732       54225.446
# 31442                192.594  ...          9.732       54225.446
# 31443                186.693  ...          9.732       54225.446
# 31444                171.449  ...          9.732       54225.446
# 31445                217.666  ...          9.732       54225.446
# 31446                207.998  ...          9.732       54225.446
# 31447                190.923  ...          9.732       54225.446
# 31448                236.938  ...          9.732       54225.446
# 31449                197.878  ...          9.732       54225.446
# 31450                169.162  ...          9.732       54225.446
# 31451                169.917  ...          9.732       54225.446
# 31452                186.506  ...          9.732       54225.446
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 31433              1.2                151.089                10.79
# 31434              1.2                151.089                10.79
# 31435              1.2                151.089                10.79
# 31436              1.2                151.089                10.79
# 31437              1.2                151.089                10.79
# 31438              1.2                151.089                10.79
# 31439              1.2                151.089                10.79
# 31440              1.2                151.089                10.79
# 31441              1.2                151.089                10.79
# 31442              1.2                151.089                10.79
# 31443              1.2                151.089                10.79
# 31444              1.2                151.089                10.79
# 31445              1.2                151.089                10.79
# 31446              1.2                151.089                10.79
# 31447              1.2                151.089                10.79
# 31448              1.2                151.089                10.79
# 31449              1.2                151.089                10.79
# 31450              1.2                151.089                10.79
# 31451              1.2                151.089                10.79
# 31452              1.2                151.089                10.79
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 31433            19.1          24.6                     NaN
# 31434            19.1          24.6                     NaN
# 31435            19.1          24.6                     NaN
# 31436            19.1          24.6                     NaN
# 31437            19.1          24.6                     NaN
# 31438            19.1          24.6                     NaN
# 31439            19.1          24.6                     NaN
# 31440            19.1          24.6                     NaN
# 31441            19.1          24.6                     NaN
# 31442            19.1          24.6                     NaN
# 31443            19.1          24.6                     NaN
# 31444            19.1          24.6                     NaN
# 31445            19.1          24.6                     NaN
# 31446            19.1          24.6                     NaN
# 31447            19.1          24.6                     NaN
# 31448            19.1          24.6                     NaN
# 31449            19.1          24.6                     NaN
# 31450            19.1          24.6                     NaN
# 31451            19.1          24.6                     NaN
# 31452            19.1          24.6                     NaN
#
#       hospital_beds_per_thousand  life_expectancy
# 31433                       2.77            78.86
# 31434                       2.77            78.86
# 31435                       2.77            78.86
# 31436                       2.77            78.86
# 31437                       2.77            78.86
# 31438                       2.77            78.86
# 31439                       2.77            78.86
# 31440                       2.77            78.86
# 31441                       2.77            78.86
# 31442                       2.77            78.86
# 31443                       2.77            78.86
# 31444                       2.77            78.86
# 31445                       2.77            78.86
# 31446                       2.77            78.86
# 31447                       2.77            78.86
# 31448                       2.77            78.86
# 31449                       2.77            78.86
# 31450                       2.77            78.86
# 31451                       2.77            78.86
# 31452                       2.77            78.86
#
# [20 rows x 34 columns]

# %%
plt.figure()
plt.plot(df_usa.date, df_usa.total_cases_per_million)
plt.title("Total US Cases")
plt.xlabel("Date")
plt.ylabel("Cases")
plt.show()
